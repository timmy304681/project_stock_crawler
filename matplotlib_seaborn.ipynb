# %%
import matplotlib
matplotlib.matplotlib_fname()
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

#turn off warnings
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
TSMC = pd.read_csv('2330stk.txt', sep='\t', index_col='Date')
TSMC.index = pd.to_datetime(TSMC.index) # 把index轉成datetime型態

Close = TSMC.Close
Open = TSMC.Open
print(Close)

fig = plt.figure()
plt.plot(Close['2016'], '-' , label="收盤價", marker=">")
plt.plot(Open['2016'], '-' , label="開盤價", marker="*")
plt.title('台積電 2016年收盤價/收盤價曲線',loc='right')
# loc->title的位置
plt.xlabel('日期')
plt.ylabel('收盤價')
plt.grid(True, axis='y')
plt.legend()
# Out:
# Date
# 2016-01-04    134.24
# 2016-01-05    132.79
# 2016-01-06    130.39
# 2016-01-07    127.98
# 2016-01-08    128.94
#                ...
# 2016-12-26    179.50
# 2016-12-27    180.00
# 2016-12-28    182.00
# 2016-12-29    180.00
# 2016-12-30    181.50
# Name: Close, Length: 244, dtype: float64

# %%
'''
柱狀圖Bar Chart：bar()、barh()
可以顯示每個數據區間坐落的樣本數。
語法：pyplot.bar(x, height, width, bottom, *args)
x-> 設定x軸
height->高度
width-> 寬度
bottom-> 柱子底部的y座標
範例：顯示台積電2016年的收盤價在哪個區間比較多
'''
barValue = [0,0,0,0,0,0]
for i in Close:
    if i > 190:
        barValue[5]+=1
    if i > 180:
        barValue[4]+=1
    if i > 170:
        barValue[3]+=1
    if i > 160:
        barValue[2]+=1
    if i > 150:
        barValue[1]+=1
    else:
        barValue[0]+=1
fig = plt.figure()
plt.bar([140,150,160,170,180,190], height=barValue , width=5.2, bottom=2.0)
# Out:
# <BarContainer object of 6 artists>

# %%
'''
用相同的數據繪製水平的柱狀圖
語法：bar(y, width, height, *args)
y-> 設定x軸
width->寬度
height-> 高度
'''
fig = plt.figure()
plt.barh([140,150,160,170,180,190], barValue , height=5.2)
# Out:
# <BarContainer object of 6 artists>

# %%
#使用台積電的開盤價、最高價、最低價、和收盤價這四個數據來繪製

import numpy as np
boxData = TSMC.iloc[:,:4]
fig = plt.figure()
plt.boxplot(np.array(boxData), labels=('收盤價','開盤價','最高價','最低價'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2999c00cac0>,
#   <matplotlib.lines.Line2D at 0x2999c00cd90>,
#   <matplotlib.lines.Line2D at 0x2999c01cee0>,
#   <matplotlib.lines.Line2D at 0x2999c02c1f0>,
#   <matplotlib.lines.Line2D at 0x2999c036310>,
#   <matplotlib.lines.Line2D at 0x2999c0365e0>,
#   <matplotlib.lines.Line2D at 0x2999c048700>,
#   <matplotlib.lines.Line2D at 0x2999c0489d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2999c01c160>,
#   <matplotlib.lines.Line2D at 0x2999c01c370>,
#   <matplotlib.lines.Line2D at 0x2999c02c4c0>,
#   <matplotlib.lines.Line2D at 0x2999c02c790>,
#   <matplotlib.lines.Line2D at 0x2999c0368b0>,
#   <matplotlib.lines.Line2D at 0x2999c036b80>,
#   <matplotlib.lines.Line2D at 0x2999c048ca0>,
#   <matplotlib.lines.Line2D at 0x2999c048f70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2999c00c7f0>,
#   <matplotlib.lines.Line2D at 0x2999c01cc10>,
#   <matplotlib.lines.Line2D at 0x2999c036040>,
#   <matplotlib.lines.Line2D at 0x2999c048430>],
#  'medians': [<matplotlib.lines.Line2D at 0x2999c01c640>,
#   <matplotlib.lines.Line2D at 0x2999c02ca60>,
#   <matplotlib.lines.Line2D at 0x2999c036e50>,
#   <matplotlib.lines.Line2D at 0x2999c052280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2999c01c910>,
#   <matplotlib.lines.Line2D at 0x2999c02cd30>,
#   <matplotlib.lines.Line2D at 0x2999c048160>,
#   <matplotlib.lines.Line2D at 0x2999c052550>],
#  'means': []}

# %%
# basic
import numpy as np
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# seaborn
import seaborn as sns


series = pd.Series(np.random.randn(1000))
series.plot(kind='hist')
# 或者可以使用plot.hist(ironman_series)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
series.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df = sns.load_dataset('flights')
print(df)
df = df.pivot(index='month', columns='year', values='passengers')
df.sum().plot(kind="bar")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <AxesSubplot:xlabel='year'>

# %%
sns.barplot(df.sum().index,df.sum().values)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
np_x = np.linspace(1, 14, 100) #產生一個1~14的等差數列
np_y1 = np.sin(np_x)
np_y2 = np.sin(np_x+2)*1.25

def drawPlot():
    plt.plot(np_x, np_y1)
    plt.plot(np_x, np_y2)
    
def drawPlotFour():
    for i in range(4):
        plt.plot(np_x, np.sin(np_x+i)*(i+0.75), label="sin(x+i)*(i+0.75)")
    plt.legend()

drawPlot()

# %%
sns.set_style('whitegrid')
drawPlot()
sns.set()

# %%
sns.set_context('talk')
drawPlot()

# %%
drawPlotFour()

# %%
with sns.axes_style('white'):
    drawPlotFour()

# %%
sns.palplot(sns.color_palette())

# %%
sns.set_palette(sns.color_palette('bright'))
drawPlotFour()
